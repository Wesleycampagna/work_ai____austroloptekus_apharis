# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import reader as read


def plot_image(image):
    img = mpimg.imread(image)
    plt.imshow(img)
    plt.show()

# %%
# arquivo de entrada
reader = read.reader()
matriz_p = reader.createMatrix('inputpath')

for element in matriz_p:
    print(element)
# Out:
# [0, 0, 3, 4, 4, 1]
# [3, 3, 0, 0, 1, 2]
# [4, 0, 0, 1, 0, 1]
# [2, 2, 2, 3, 2, 2]

# %%
saida = reader.createMatrix('saida-genetico.txt')

print(saida)
# Out:
# [[3, 2, 4, 4, 1]]

# %%
# a média da média dos valores da geração dada as 10 repetições 
plot_image('geneticFiles/fitness.png')

# %%
plot_image('geneticFiles/repeat-1.png')

# %%
plot_image('geneticFiles/repeat-2.png')

# %%
plot_image('geneticFiles/repeat-3.png')

# %%
plot_image('geneticFiles/repeat-4.png')

# %%
plot_image('geneticFiles/repeat-5.png')

# %%
plot_image('geneticFiles/repeat-6.png')

# %%
plot_image('geneticFiles/repeat-7.png')

# %%
plot_image('geneticFiles/repeat-8.png')

# %%
plot_image('geneticFiles/repeat-9.png')

# %%
plot_image('geneticFiles/repeat-10.png')

# %%
    
plot_image('geneticFiles/graph.png')
